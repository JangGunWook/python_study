# %%
# 파이썬의 조건문은
# 조건문 안의 영역을 들여쓰기로 구분

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 조건문 if
if 2>1:
    print('해당 조건식은 true 입니다')
if 2<1:  # false 조건문 안을 확인x 셀 실행 멈춤
    print("조건문 안이에요")
# Out:
# 해당 조건식은 true 입니다

# %%
# 들여쓰기 중요성
if True:
    print('조건문 안 실행문장')
print('조건문 밖 실행문장')
# Out:
# 조건문 안 실행문장
# 조건문 밖 실행문장

# %%
if False:
    print('조건문 안 실행문장')
print('조건문 밖 실행문장')
# Out:
# 조건문 밖 실행문장

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
money = 11000
if money >= 10000:
    print("택시를 탄다.")

money = 9000
if money >= 10000:
    print("택시를 탄다.")
# Out:
# 택시를 탄다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# if - else
if True:
    print('실행문장1')
else:
    print('실행문장2')
# Out:
# 실행문장1

# %%
if True:
    print('실행문장1')
else:
    print('실행문장2')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
money = 11000
if money >= 10000:
    print("택시를 탄다.")
else:
    print('버스를 탄다')
    

money = 9000
if money >= 10000:
    print("택시를 탄다.")
else:
    print('버스를 탄다')
# Out:
# 택시를 탄다.
# 버스를 탄다

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = int(input("정수 입력 >> "))

if num%3==0 and num%5==0 :
    print('3과 5의 배수입니다')
else:
    print('3과 5의 배수가 아닙니다')
# Out:
# 정수 입력 >> 30
# 3과 5의 배수입니다

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num1 = int(input("첫 번째 정수 입력 >> "))
num2 = int(input("두 번째 정수 입력 >> "))

if num1 > num2:
    print('첫 번째 정수가 더 큽니다')
elif num1 == num2:
    print("두 수가 똑같습니다!")
else:
    print("두 번재 정수가 더 큽니다")
# Out:
# 첫 번째 정수 입력 >> 10
# 두 번째 정수 입력 >> 7
# 첫 번째 정수가 더 큽니다

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
money = int(input("금액 넣기 >>"))
manue = int(input("메뉴번호 입력>>"))

if manue== 1:
    if money>=600:
        money -= 600
        print(f"거스름돈 >> 1000원 {money//1000}개 500원 {money%1000//500}개 100원 {money%1000%500//100}개")
    elif money < 600:
        pring("잔액부족")
elif manue==2:
    if money>=800:
        money -= 800
        print(f"거스름돈 >> 1000원 {money//1000}개 500원 {money%1000//500}개 100원 {money%1000%500//100}개")
    elif money <800:
        pring("잔액부족")
elif manue==3:
    if money>=1000:
        money -= 1000
        print(f"거스름돈 >> 1000원 {money//1000}개 500원 {money%1000//500}개 100원 {money%1000%500//100}개")
    elif money <1000:
        pring("잔액부족")
# Out:
# 금액 넣기 >>5000
# 메뉴번호 입력>>2
# 거스름돈 >> 1000원 4개 500원 0개 100원 2개
